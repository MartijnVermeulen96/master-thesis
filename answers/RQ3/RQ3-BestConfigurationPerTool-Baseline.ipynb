# %% [markdown]
# # Results for RQ3

# %%
import os 
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import prettytable
import pickle 
import sklearn
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize as pre_normalize
import sklearn.ensemble
import sklearn.neural_network
import matplotlib.pyplot as plt
import itertools
from contextlib import redirect_stdout, redirect_stderr
import time
import ipywidgets as widgets
from IPython.display import clear_output
import seaborn as sns
import math

cwd = os.getcwd()
os.chdir('../../')
import errorAPI
from errorAPI.dataset import Dataset
os.chdir(cwd)
f = open(os.devnull, 'w')
sns.set_context("paper")
sns.set_style("darkgrid")

# %%
## Config

sql_string = 'postgresql://postgres:postgres@localhost:5432/error_detection'
profiles_path = '../../dataset_profiles.p'
dataset_path = '../../datasets'
rq2_path = '../RQ2'
all_regressors = errorAPI.Profiler.available_regressors

experiment = 15

# %%
experiment_results = {x: pickle.load(open(os.path.join(rq2_path,x), 'rb')) for x in os.listdir(rq2_path) if x.startswith(str(experiment)) and x.endswith("_MSE.p")}
experiment_data = pickle.load(open([os.path.join(rq2_path,x) for x in os.listdir(rq2_path) if x.startswith(str(experiment)) and x.endswith("_data.p")][0], 'rb'))

number_of_strategies = experiment_data["number_of_strategies"]
number_of_filtered_strategies = experiment_data["number_of_filtered_strategies"]
all_configs = experiment_data["all_configs"]
dataset_profiles = experiment_data["dataset_profiles"]
# dataset_profiles = pickle.load(open(profiles_path, 'rb'))
performance_results = experiment_data["performance_results"]
f1_threshold = experiment_data["f1_threshold"]
max_human_cost = experiment_data["max_human_cost"]

datasets = list(set(dataset_profiles["name"]))

# %%
print("Total num of strategies:", number_of_strategies)
print("Total num of filtered strategies:", number_of_filtered_strategies)
# Out:
# Total num of strategies: 165
# Total num of filtered strategies: 93

# %%
tool_names = list(set([x[0] for x in all_configs]))
tool_names
# Out:
# ['FAHES', 'Raha', 'ForbiddenItemSets', 'dBoost', 'KATARA', 'ActiveClean']

# %% [markdown]
# ## Ranking scores best configurations per tool

# %%
chosen_metric = "cell_f1"

# %%
with open("baseline_profilers.p", "rb") as f:
    profilers = pickle.load(f)
    
f1_profiler = profilers["cell_f1"]
rec_profiler = profilers["cell_rec"]
prec_profiler = profilers["cell_prec"]
combined_profiler = errorAPI.CombinedProfiler(prec_profiler, rec_profiler, f1_profiler)

# %%
profilers_ndcg = ["prec_profiler", "rec_profiler", "f1_profiler", "combined_profiler"]
chosen_tools = ["Raha", "dBoost"]

# %%
K = 10
L = 10

# %%
all_tools_results = []
for which_profiler in profilers_ndcg:
    print("-="*10)
    print(which_profiler)
    print("-="*10)
    
    for tool_name in chosen_tools:
        tool_filter = [tool_name]
        ndcg_results = []

        for dataset_name in datasets:
            ndcg, ranking_estimate, ranking_best = eval(which_profiler).get_ndcg(dataset_name, K, L, tool_filter)
            if ranking_best["dcg_i"].sum() > 0:
                ndcg_results.append({"Dataset": dataset_name, "NDCG": ndcg})

        ndcg_df = pd.DataFrame(ndcg_results).sort_values("NDCG", ascending=False)
        plt.figure()
        fig = sns.barplot(y="Dataset", x="NDCG", data=ndcg_df, orient="h", palette="Blues_r").set_title("NDCG for F1, for " + tool_name)
        fig.figure.savefig(str(experiment) + "_baseline_" + which_profiler + "_NDCG_" + tool_name + ".pdf", bbox_inches="tight")
        all_tools_results.append({"Profiler": which_profiler, "Tool": tool_name, "Mean NDCG": ndcg_df["NDCG"].mean()})
# Out:
# -=-=-=-=-=-=-=-=-=-=
# prec_profiler
# -=-=-=-=-=-=-=-=-=-=
# -=-=-=-=-=-=-=-=-=-=
# rec_profiler
# -=-=-=-=-=-=-=-=-=-=
# -=-=-=-=-=-=-=-=-=-=
# f1_profiler
# -=-=-=-=-=-=-=-=-=-=
# -=-=-=-=-=-=-=-=-=-=
# combined_profiler
# -=-=-=-=-=-=-=-=-=-=

# %%
all_tools_df = pd.DataFrame(all_tools_results).sort_values("Mean NDCG", ascending=False)

# %%
sns.barplot(x="Tool", y="Mean NDCG", hue="Profiler", data=all_tools_df)

# %%
config_stats_baseline = all_tools_df[["Tool", "Profiler", "Mean NDCG"]].sort_index().sort_values(["Tool"])

# %%
with open("config_stats_estimator.p", "rb") as f:
    config_stats_estimator = pickle.load(f)

# %%
grouped_Raha_baseline = config_stats_baseline[config_stats_baseline["Tool"] == "Raha"].set_index("Profiler").rename(columns={"Mean NDCG": "Baseline Mean NDCG"})
grouped_Raha_estimator = config_stats_estimator[config_stats_estimator["Tool"] == "Raha"].set_index("Profiler").rename(columns={"Mean NDCG": "Estimator Mean NDCG"})
result_Raha = grouped_Raha_baseline.join(grouped_Raha_estimator, lsuffix="_", rsuffix="-").iloc[:, [1,3]]
result_Raha["Improvement"] = result_Raha.iloc[:, 1] - result_Raha.iloc[:, 0]
result_Raha = result_Raha.applymap(lambda x: round(x, 3))
result_Raha
# Out:
#                    Baseline Mean NDCG  Estimator Mean NDCG  Improvement
# Profiler
# prec_profiler                   0.652                0.802        0.150
# rec_profiler                    0.913                0.970        0.057
# f1_profiler                     0.731                0.824        0.092
# combined_profiler               0.702                0.807        0.105

# %%
grouped_dBoost_baseline = config_stats_baseline[config_stats_baseline["Tool"] == "dBoost"].set_index("Profiler").rename(columns={"Mean NDCG": "Baseline Mean NDCG"})
grouped_dBoost_estimator = config_stats_estimator[config_stats_estimator["Tool"] == "dBoost"].set_index("Profiler").rename(columns={"Mean NDCG": "Estimator Mean NDCG"})
result_dBoost = grouped_dBoost_baseline.join(grouped_dBoost_estimator, lsuffix="_", rsuffix="-").iloc[:, [1,3]]
result_dBoost["Improvement"] = result_dBoost.iloc[:, 1] - result_dBoost.iloc[:, 0]
result_dBoost = result_dBoost.applymap(lambda x: round(x, 3))
result_dBoost
# Out:
#                    Baseline Mean NDCG  Estimator Mean NDCG  Improvement
# Profiler
# prec_profiler                   0.565                0.647        0.082
# rec_profiler                    0.911                0.829       -0.083
# f1_profiler                     0.521                0.492       -0.029
# combined_profiler               0.424                0.572        0.149

# %%
print(result_Raha.to_latex(caption="Mean NDCG comparison for configuration ranking Raha", escape=False))
# Out:
# \begin{table}
# \centering
# \caption{Mean NDCG comparison for configuration ranking Raha}
# \begin{tabular}{lrrr}
# \toprule
# {} &  Baseline Mean NDCG &  Estimator Mean NDCG &  Improvement \\
# Profiler          &                     &                      &              \\
# \midrule
# prec_profiler     &               0.652 &                0.802 &        0.150 \\
# rec_profiler      &               0.913 &                0.970 &        0.057 \\
# f1_profiler       &               0.731 &                0.824 &        0.092 \\
# combined_profiler &               0.702 &                0.807 &        0.105 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
print(result_dBoost.to_latex(caption="Mean NDCG comparison for configuration ranking dBoost", escape=False))
# Out:
# \begin{table}
# \centering
# \caption{Mean NDCG comparison for configuration ranking dBoost}
# \begin{tabular}{lrrr}
# \toprule
# {} &  Baseline Mean NDCG &  Estimator Mean NDCG &  Improvement \\
# Profiler          &                     &                      &              \\
# \midrule
# prec_profiler     &               0.565 &                0.647 &        0.082 \\
# rec_profiler      &               0.911 &                0.829 &       -0.083 \\
# f1_profiler       &               0.521 &                0.492 &       -0.029 \\
# combined_profiler &               0.424 &                0.572 &        0.149 \\
# \bottomrule
# \end{tabular}
# \end{table}
